# %%
import numpy as np
import seaborn as sb
import pandas as pd

# %% [markdown]
# Kode diatas untuk import library di python

# %%
suicide=pd.read_csv("who_suicide_statistics.csv")
suicide
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>year</th>
#       <th>sex</th>
#       <th>age</th>
#       <th>suicides_no</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>Albania</td>
#       <td>1985</td>
#       <td>female</td>
#       <td>15-24 years</td>
#       <td>NaN</td>
#       <td>277900.0</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>Albania</td>
#       <td>1985</td>
#       <td>female</td>
#       <td>25-34 years</td>
#       <td>NaN</td>
#       <td>246800.0</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Albania</td>
# ...
